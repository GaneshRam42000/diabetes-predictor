# %% [markdown]
# # Exploration data analysis of visualization and training a model by given attributes

# %%
#import library packages
import pandas as p
import matplotlib.pyplot as plt
import seaborn as s
import numpy as n

# %%
data = p.read_csv("diabetes.csv")

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
data.shape
# Out:
# (2000, 9)

# %%
#diabates possitive reports
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#missing values
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data["Outcome"].value_counts()
# Out:
# 0    1316
# 1     684
# Name: Outcome, dtype: int64

# %%
data.shape
# Out:
# (2000, 9)

# %%
# diadbetes pesion with blood pressure 
plt.figure(figsize=(16,4))
plt.subplot(1,2,1)
plt.hist(data['BMI'])
plt.title("BMI")
plt.xlabel("BMI VRange")
plt.ylabel("count")
plt.subplot(1,2,2)
plt.hist(data['BloodPressure'])
plt.xlabel('BloodPressure')
plt.title('BloodPressure Range')
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(16,6))
s.countplot(x="Age",data=data)
plt.show()

# %%
# result based on age
plt.figure(figsize=(16,6))
s.countplot(x='Age',hue='Outcome',data=data)
plt.show()

# %%
plt.figure(figsize=(16,4))

plt.scatter(data['BMI'],data['Glucose'])
plt.xlabel("Age")
plt.ylabel("Glucose")
plt.show()

# %%
plt.figure(figsize=(16,4))

plt.scatter(data['BloodPressure'],data['Glucose'])
plt.xlabel('BloodPressure')
plt.ylabel("Glucose")
plt.show()

# %%
boxplot = data.boxplot(column = ['Glucose'], by = 'Outcome',figsize = (8,5), fontsize = 15)
plt.show()
boxplot = data.boxplot(column = ['BloodPressure'], by = 'Outcome',figsize = (8,5), fontsize = 15)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,10))
s.heatmap(data.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,15)) #(width,height)
plt.subplot(3,3,1) 
s.boxplot(x='Glucose', data=data);
plt.subplot(3,3,2)
s.boxplot(x='BloodPressure', data=data);
plt.subplot(3,3,3)
s.boxplot(x='SkinThickness', data=data);
plt.subplot(3,3,4)
s.boxplot(x='Insulin', data=data);
plt.subplot(3,3,5)
s.boxplot(x='BMI', data=data);
plt.subplot(3,3,6)
s.boxplot(x='DiabetesPedigreeFunction', data=data);
plt.subplot(3,3,7)
s.boxplot(x='Age', data=data);

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#Propagation by variable
def PropByVar(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(10,10), autopct='%1.2f%%', fontsize = 12)
    ax.set_title(variable + ' \n', fontsize = 15)
    return n.round(dataframe_pie/df.shape[0]*100,2)

PropByVar(data, 'Outcome')
# Out:
# 0    65.8
# 1    34.2
# Name: Outcome, dtype: float64

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
p.plotting.scatter_matrix(data, alpha=0.05, figsize=(18,10), diagonal='hist')
axis = 'off'

plt.show()

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0            2       76             16             28        0   16
# 1            0       22             28             24       78   21
# 2            0       83              0              0        0   27
# 3            0       73             20             35      134   25
# 4            1       77             16             34      172   23
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                         0   26        1
# 1                         0    2        0
# 2                         0   10        1
# 3                         0    3        1
# 4                         0    0        0
